# %% [markdown]
# # Exploratory Data Analysis
# **Author:** Shais Daimi
# **Branch:** dev/shais
# **Dataset:** ai4i2020_time_series.csv (125 columns, 10,000 rows)
#
# All plots are generated via functions from `eda_analysis.py`

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
from pathlib import Path

from eda import run_time_series_eda

print('Imports done ✅')
# Out:
# Imports done ✅

# %% [markdown]
# ## 2. Load Dataset

# %%
BASE_DIR = Path().resolve().parent
df = pd.read_csv(BASE_DIR / 'Dataset' / 'ai4i2020_time_series.csv')

# Restore Timestamp as index
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df = df.set_index('Timestamp')

print('Dataset loaded ✅')
print('Shape:', df.shape)
df.head(3)
# Out:
# Dataset loaded ✅
# Shape: (10000, 124)
#                      Type  Air temperature [K]  Process temperature [K]  \
# Timestamp
# 2026-01-01 00:00:00     1                298.1                    308.6
# 2026-01-01 00:01:00     0                298.2                    308.7
# 2026-01-01 00:02:00     0                298.1                    308.5
#
#                      Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  \
# Timestamp
# 2026-01-01 00:00:00                    1551         42.8                0
# 2026-01-01 00:01:00                    1408         46.3                3
# 2026-01-01 00:02:00                    1498         49.4                5
#
#                      Machine failure  TWF  HDF  PWF  ...  power_tool_dev_15  \
# Timestamp                                            ...
# 2026-01-01 00:00:00                0    0    0    0  ...                0.0
# 2026-01-01 00:01:00                0    0    0    0  ...             -596.2
# 2026-01-01 00:02:00                0    0    0    0  ...             5476.4
#
#                      temp_diff_tool_mean_15  temp_diff_tool_std_15  \
# Timestamp
# 2026-01-01 00:00:00               10.500000               0.000000
# 2026-01-01 00:01:00               10.500000               0.000000
# 2026-01-01 00:02:00               10.466667               0.057735
#
#                      temp_diff_tool_dev_15  Torque [Nm]_lag_1  \
# Timestamp
# 2026-01-01 00:00:00               0.000000               42.8
# 2026-01-01 00:01:00               0.000000               42.8
# 2026-01-01 00:02:00              -0.066667               46.3
#
#                      Rotational speed [rpm]_lag_1  power_lag_1  \
# Timestamp
# 2026-01-01 00:00:00                        1551.0      66382.8
# 2026-01-01 00:01:00                        1551.0      66382.8
# 2026-01-01 00:02:00                        1408.0      65190.4
#
#                      Torque [Nm]_lag_2  Rotational speed [rpm]_lag_2  \
# Timestamp
# 2026-01-01 00:00:00               42.8                        1551.0
# 2026-01-01 00:01:00               42.8                        1551.0
# 2026-01-01 00:02:00               42.8                        1551.0
#
#                      power_lag_2
# Timestamp
# 2026-01-01 00:00:00      66382.8
# 2026-01-01 00:01:00      66382.8
# 2026-01-01 00:02:00      66382.8
#
# [3 rows x 124 columns]

# %% [markdown]
# ## 3. Time Series EDA

# %%
run_time_series_eda(df)
# Out:
# 🚀 Initializing Structural Time Series EDA under theme #0f1117...
# ✅ Saved: eda_visualization\sensor_trends.png
# ✅ Saved: eda_visualization\rolling_stats.png
# ✅ Saved: eda_visualization\tool_cycle_behavior.png
# ✅ Saved: eda_visualization\lag_analysis.png
# ✅ Saved: eda_visualization\failure_timeline.png
#
# 📦 Operational Assets Generated Successfully. Outputs saved to directory: 'eda_visualization/'
