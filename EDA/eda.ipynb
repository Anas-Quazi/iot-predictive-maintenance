# %% [markdown]
# # Exploratory Data Analysis
# **Author:** Shais Daimi
# **Branch:** dev/shais
# **Dataset:** ai4i2020_time_series.csv (125 columns, 10,000 rows)
#
# All plots are generated via functions from `eda_analysis.py`

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
from pathlib import Path

from eda_analysis import run_time_series_eda

print('Imports done ✅')

# %% [markdown]
# ## 2. Load Dataset

# %%
BASE_DIR = Path().resolve().parent.parent
df = pd.read_csv(BASE_DIR / 'Dataset' / 'ai4i2020_time_series.csv')

# Restore Timestamp as index
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df = df.set_index('Timestamp')

print('Dataset loaded ✅')
print('Shape:', df.shape)
df.head(3)

# %% [markdown]
# ## 3. Time Series EDA

# %%
run_time_series_eda(df)
